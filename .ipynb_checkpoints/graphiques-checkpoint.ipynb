# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

x = iris.data
y = iris.target
names = list(iris.target_names)

print(f'x contient {x.shape[0]} exemples et {x.shape[1]} variables')
print(f'il y a {np.unique(y).size} classes')
# Out:
# x contient 150 exemples et 4 variables
# il y a 3 classes

# %% [markdown]
# ## (5) Graphique de classification avec plt.scatter

# %%
plt.scatter(x[:,0], x[:,1], c =y, alpha=0.5, s=x[:,2]*50)
plt.xlabel('longueur sépal')
plt.ylabel('largeur sépal')
# Out:
# Text(0, 0.5, 'largeur sépal')

# %% [markdown]
# ## (4) Graphique 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection='3d')
ax.scatter(x[:,0],x[:,1],x[:,2], c = y)

# %%
  f = lambda x,y: np.sin(x) + np.cos(x+y)

# %%
X = np.linspace(0,5,100)
Y = np.linspace(0,5,100)
X,Y = np.meshgrid(X,Y)
Z = f(X,Y)

# %%
Z.shape
# Out:
# (100, 100)

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X,Y,Z, cmap ='plasma')

# %% [markdown]
# ## (3) Histogramme

# %%
plt.hist(x[:,0], bins=30)
plt.hist(x[:,1], bins=30)
# Out:
# (array([ 1.,  0.,  3.,  4.,  0.,  3.,  8.,  5.,  9., 14.,  0., 10., 26.,
#         11.,  0., 13.,  6., 12.,  6.,  4.,  0.,  3.,  6.,  2.,  0.,  1.,
#          1.,  1.,  0.,  1.]),
#  array([2.  , 2.08, 2.16, 2.24, 2.32, 2.4 , 2.48, 2.56, 2.64, 2.72, 2.8 ,
#         2.88, 2.96, 3.04, 3.12, 3.2 , 3.28, 3.36, 3.44, 3.52, 3.6 , 3.68,
#         3.76, 3.84, 3.92, 4.  , 4.08, 4.16, 4.24, 4.32, 4.4 ]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist2d(x[:,0], x[:,1], cmap='Blues')
plt.xlabel('longueur sépal')
plt.ylabel('largeur sépal')
plt.colorbar()

# %%
from scipy import misc
face = misc.face(gray=True)
# plt.imshow(face, cmap='gray')
plt.hist(face.ravel(),bins=255)
plt.show()
# Out:
# /tmp/ipykernel_136844/1085209953.py:2: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face(gray=True)

# %% [markdown]
# ## (2) Contour plot

# %%
plt.contour(X,Y,Z,20, colors='black')

# %%
plt.contour(X,Y,Z,20, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# # (1) Imshow

# %%
plt.imshow(face)

# %%
plt.imshow(np.corrcoef(x.T), cmap='Blues')
plt.colorbar()
plt.show()

# %%
dataset = { f"experience {i}" : np.random.randn(100) for i in range(4)}

# %%
def graphique(deta):
    n = len(data)
    plt.figure(figsize=(12,8))
    for k, i in zip(data.key(), range(1,n+1)) :
        plt.subplot(n,1,i)
        plt.plot(data[k])
        plt.title(k)
    plt.show()

# %%
graphique(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 graphique(dataset)
#
# Cell In[37], line 2, in graphique(deta)
#       1 def graphique(deta):
# ----> 2     n=len(data)
#       3     plt.figure(figsize=(12,8))
#       4     for k, i in zip(data.key(), range(1,n+1)) :
#
# NameError: name 'data' is not defined
